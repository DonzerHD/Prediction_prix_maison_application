# %% [markdown]
# # Predictive modelisation

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df_model = pd.read_csv('data/kc_house_data_clean_model.csv')
df_model_knn = pd.read_csv('data/kc_house_data_clean_model.csv')

# %% [markdown]
# # KNN

# %%
X = df_model_knn.drop(columns=['price'])
y = df_model_knn['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Entrainement du modèle
knn = KNeighborsRegressor(n_neighbors=7)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
knn.score(X_test, y_test)
# Out:
# 0.46601358005570725

# %%
predict_X = knn.predict(X)
df_model_knn['predict_price'] = predict_X.round(0)
pd.set_option('display.max_rows', 100)
df_model_knn[['price', 'predict_price']].head(70)
# Out:
#         price  predict_price
# 0    221900.0       438200.0
# 1    538000.0       490636.0
# 2    180000.0       256286.0
# 3    604000.0       536214.0
# 4    510000.0       429693.0
# 5   1225000.0       665279.0
# 6    257500.0       331536.0
# 7    291850.0       226000.0
# 8    229500.0       336429.0
# 9    323000.0       453221.0
# 10   662500.0       785471.0
# 11   468000.0       309286.0
# 12   310000.0       341714.0
# 13   400000.0       310100.0
# 14   530000.0       502496.0
# 15   650000.0       875714.0
# 16   395000.0       440286.0
# 17   485000.0       344571.0
# 18   189000.0       303143.0
# 19   230000.0       316250.0
# 20   385000.0       463000.0
# 21   285000.0       372421.0
# 22   252700.0       295164.0
# 23   329000.0       366514.0
# 24   233000.0       458731.0
# 25   937000.0       805857.0
# 26   667000.0       589286.0
# 27   438000.0       310154.0
# 28   719000.0       624777.0
# 29   580500.0       468685.0
# 30   280000.0       391687.0
# ...

# %% [markdown]
# # Linear regression

# %%
X_train, X_test, y_train, y_test = train_test_split(df_model.drop('price', axis=1), df_model['price'], test_size=0.10, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(X_test)

# %%
print('R² :', r2_score(y_test, predictions))
# Out:
# R² : 0.8424895395710692

# %%
df_model.head(15)
# Out:
#         price  bedrooms  bathrooms  surface  sqft_lot  floors  waterfront  \
# 0    221900.0         3       1.00     1180      5650     1.0           0
# 1    538000.0         3       2.25     2570      7242     2.0           0
# 2    180000.0         2       1.00      770     10000     1.0           0
# 3    604000.0         4       3.00     1960      5000     1.0           0
# 4    510000.0         3       2.00     1680      8080     1.0           0
# 5   1225000.0         4       4.50     5420    101930     1.0           0
# 6    257500.0         3       2.25     1715      6819     2.0           0
# 7    291850.0         3       1.50     1060      9711     1.0           0
# 8    229500.0         3       1.00     1780      7470     1.0           0
# 9    323000.0         3       2.50     1890      6560     2.0           0
# 10   662500.0         3       2.50     3560      9796     1.0           0
# 11   468000.0         2       1.00     1160      6000     1.0           0
# ...

# %%
# predit le prix d'une maison dans le dataset
predict_lr_X = lr.predict(X)
df_model['predict_price'] = predict_lr_X.round(0)
pd.set_option('display.max_rows', 100)
df_model[['price', 'predict_price']].head(70)
# Out:
#         price  predict_price
# 0    221900.0       226117.0
# 1    538000.0       518416.0
# 2    180000.0       240899.0
# 3    604000.0       551591.0
# 4    510000.0       498274.0
# 5   1225000.0      1248228.0
# 6    257500.0       227115.0
# 7    291850.0       176894.0
# 8    229500.0       350037.0
# 9    323000.0       304870.0
# 10   662500.0       732157.0
# 11   468000.0       516065.0
# 12   310000.0       362985.0
# 13   400000.0       420133.0
# 14   530000.0       557213.0
# 15   650000.0       774523.0
# 16   395000.0       340300.0
# 17   485000.0       598224.0
# 18   189000.0       200110.0
# 19   230000.0       194019.0
# 20   385000.0       364353.0
# 21   285000.0       312727.0
# 22   252700.0       147712.0
# 23   329000.0       412310.0
# 24   233000.0       230372.0
# 25   937000.0       785699.0
# 26   667000.0       820930.0
# 27   438000.0       516968.0
# 28   719000.0       656615.0
# 29   580500.0       563717.0
# 30   280000.0       262180.0
# ...
